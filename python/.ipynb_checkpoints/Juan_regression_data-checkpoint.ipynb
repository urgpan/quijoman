# %%
# %%html
# <img src="data:image/png;base64,...", width = 200, height=200>
# Out:
# <img src="data:image/png;base64,...", width = 200, height=200>

# %% [markdown]
# # Project
# ## Regression Task

# %%
#!pip install h3
#!pip3 install xgboost
#!pip3 install hide_code
#!jupyter nbextension install --py hide_code
#!jupyter nbextension enable --py hide_code

# %%
import pandas as pd
import numpy as np
import datetime
import warnings

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
# %matplotlib inline

pd.set_option('display.max_columns', None)

import h3

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, cohen_kappa_score
from sklearn.utils import check_array


from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.neighbors import KNeighborsRegressor

from sklearn.preprocessing import Normalizer, PowerTransformer, QuantileTransformer, RobustScaler, MaxAbsScaler

from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

from sklearn.linear_model import LassoLars
from sklearn.linear_model import SGDClassifier, SGDRegressor
from sklearn.linear_model import TweedieRegressor
from sklearn.linear_model import Ridge, BayesianRidge
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network  import MLPClassifier
from sklearn import ensemble
from xgboost import XGBRegressor

# %% [markdown]
# ## IMPORT DATA

# %%
# Opening the file, renaming columns, general visualization
data = pd.read_excel(r'C:\Users\urgpa\OneDrive\Escritorio\Documentos\RELHACKERS\LEWORK\DAY4_0\LAB\quijoman\data\regression_data.xls')

# %% [markdown]
# ### AUXILIAR CLEANING FUNCTIONS

# %%
#knowing the year build, we can calculate the age of the house, wich i will be more useful for creating themodel.
def house_age(x):
    return int(2020 - int(x))

#datetime wont be useful for our model, thats why why convert it into years and months
def get_years(x):
    x = x.strftime("%Y")
    return int(x)

def get_months(x):
    x = x.strftime("%m")
    return int(x)

#NOT USED ON THE FINAL MODEL, Created to transform the date into seasons
def season_sold(x):
    if x == 3 or x == 4 or x == 5:
        return 1
    elif x == 6 or x == 7 or x == 8:
        return 2
    elif x == 9 or x == 10 or x == 11:
        return 3
    elif x == 12 or x == 1 or x== 2:
        return 0

#SIGN parameters, so wee dont have a lot of low value columns
def is_there_anything(x):
    if x > 0:
        return int(1)
    else:
        return int(0)

#Get the price of one sqft. This might help for predicting the model. WE CANT USE THE ACTUAL PRICE
def sqft_overall(sqft, price):
    return float(sqft / price)

#Sum columns, for example sqft above and sqft basement.
def sum_col(x,y,p):
    z = []
    for i in x:
        z.append((x[i] + y[i])/ p[i])
    return z ;

#Group long and lat by hexagons to afterward we can assign a mean prcie house vlaue by hexagon
def hex_3_point(lat, long):
    value = h3.geo_to_h3(lat=lat, lng = long, resolution = 6)
    return value

#Create a dictionary with the mean price of each hexagon related to the hexagon.
def create_dict(x,y):
    z = x
    z['price'] = y
    newData = z['price'].groupby(z['hex_3']).mean()
    avg_dict_ = newData.to_dict()
    return avg_dict_

#Apply that dictionary to a new dataset.
def apply_dict (x, d):
    x['avg_price'] = range(0,len(x.hex_3))

    for i in range(0,len(x['hex_3'])):
        x['avg_price'][i] = avg_dict[x['hex_3'][i]]
    return x

# %% [markdown]
# ### CLEANING FUNCTIONS

# %%
#APPLY all those auxiliar functions to the data set we want to clean.
def cleaning_data_0 (df):
    
    #CLEAN THE FRAME
    df.columns=list(map(lambda x: x.lower(),df.columns))
    df.columns=list(map(lambda x: x.replace(' ','_'), df.columns))
    
    #print(df.columns)
    #AGE OF THE HOUSE INTO YR BUILT
    df['house_age'] = df.yr_built.apply(house_age)
    #DATE INTO MONTHS
    df['month_sold'] = list(map(get_months, df['date']))
    #MONTHS INTO SEASONS
    #df['season'] = df.month_sold.apply(season_sold)
    #DUMMIFY IT
    #df = pd.get_dummies(df,columns=["season"])
    #GET THE YEARS
    df['year_sold'] = list(map(get_years, df['date']))
    #ROUND BATHROOMS
    df['bathrooms'] = list(map(round, df['bathrooms']))
    #ENCODE THE BASEMENT
    df['sqft_basement'] = df['sqft_basement'].apply(is_there_anything)
    #ENCODE IF IT IS RENOVATED
    df['yr_renovated'] = df['yr_renovated'].apply(is_there_anything)
    #MAKE FLOORS INTEGERS
    df['floors'] = df['floors'].apply(lambda x: int(x))
    #CREATE HEXAGON WITH LAT AND LONG
    df['hex_3'] = df.apply(lambda x: hex_3_point(x['lat'], x['long']), axis=1)
    df["hex_3"] = df["hex_3"].astype('category')
    df["hex_3"] = df["hex_3"].cat.codes.astype(int)
    
    return df

#Calculate the mean prices of the houses by hexagon and create new values as: sqft_living_price, sqft_lot_price...
#This is only for the train set, because we can only use the prices in the training set. That why we save it afterwards.
def average_prices_hex_train(df, y):
    
    #add the target
    df['avg_price'] = y
    #group prices by hexagons(without sorting)
    dataf = pd.DataFrame(df['avg_price'].groupby(df['hex_3']).mean(), columns = ['avg_price'])
    #sort hexagons by price
    dataf = dataf.sort_values('avg_price',ascending=False)
    dataf = dataf.reset_index()
    #rename columns hexagon to be prepared to set it to the real df
    #dataf = dataf.rename(columns={'hex_3': 'hex_1'})
    #reassign the 
    #df['hex_3'] = dataf['hex_3']
    #make the dict
    #avg_dict = 
    avg_dict = dict(zip(dataf.index.unique() , dataf['avg_price']))
    ind_dict = dict(zip(df.hex_3.unique() , dataf.index.unique()))
    #print(ind_dict)
    #print(dataf)
    #print(avg_dict)
    #print(df['hex_3'])
    #print(df.avg_price.value_counts())
    
    df['hex_3'] = list(map(lambda x: ind_dict[x],df['hex_3']))
    
    df['avg_price'] = list(map(lambda x: avg_dict[x],df['hex_3']))

    #df["hex_3"] = df.sort_values('avg_price',ascending=False)['hex_3']
    
    #df = apply_dict(df,avg_dict)
    df['sqft_living_price'] = df.apply(lambda x: sqft_overall(x['sqft_living'], x['avg_price']), axis=1)
    df['sqft_lot_price'] = df.apply(lambda x: sqft_overall(x['sqft_lot'], x['avg_price']), axis=1)
    df['sqft_living15_price'] = df.apply(lambda x: sqft_overall(x['sqft_living15'], x['avg_price']), axis=1)
    df['sqft_lot15_price'] = df.apply(lambda x: sqft_overall(x['sqft_lot15'], x['avg_price']), axis=1)
    #df['house_sqft_price'] = sum_col(df['sqft_living'],df['sqft_basement'], df['avg_price'])
    
    
    #df.drop('price', inplace = True)
    return df, avg_dict, ind_dict

#Apply de dictionary we created with the trainign set to the test set. And in the same way compute the sqft_living_price, sqft_lot_price...
def average_prices_hex_test(df, dicti, ind_dict):
   
    df['hex_3'] = list(map(lambda x: ind_dict[x],df['hex_3']))
    df['avg_price'] = list(map(lambda x: dicti[x],df['hex_3']))            
    #df = apply_dict(df)
    #CREATE NEW VALUES WITH THE CREATED ONES
    df['sqft_living_price'] = df.apply(lambda x: sqft_overall(x['sqft_living'], x['avg_price']), axis=1)
    df['sqft_lot_price'] = df.apply(lambda x: sqft_overall(x['sqft_lot'], x['avg_price']), axis=1)
    df['sqft_living15_price'] = df.apply(lambda x: sqft_overall(x['sqft_living15'], x['avg_price']), axis=1)
    df['sqft_lot15_price'] = df.apply(lambda x: sqft_overall(x['sqft_lot15'], x['avg_price']), axis=1)
    #df['house_sqft_price'] = sum_col(df['sqft_living'],df['sqft_basement'], df['avg_price'])

    
    return df

#Preform some cleaning that must be done at the end of the cleaning process... Such as dropping columns, or changing the index.
def final_clean(df, dropping):
    df = df.set_index('id')
    if 'price' in df.columns:
        df.drop('price', axis = 1, inplace = True)
        
    df.drop(dropping, axis = 1, inplace = True)
    return df

# %% [markdown]
# ### AUX TRANSFORMING AND MODELING FUNCTIONS

# %%
#Compute the MAPE for the metrics of the model.
def mean_absolute_percentage_error(y_true, y_pred): 
    perc_errors = np.abs((y_true - y_pred) / y_true) * 100
    mean_perc_error = np.mean(perc_errors)
    return  mean_perc_error, perc_errors

#Scale the data direcly with a scling method. Then return the scaler so we can use it afterwards with the test set.
def scale_data(x,scaler):
    ##FIT THE SCALER WITH THE DATA
    optimus_prime = scaler.fit(x)
    ##TRANSFORM IT  WITH THE FIT TRANSFORMER = OPTIMUSPRIME
    data_transf = optimus_prime.transform(x)
    ##CONVERT INTO A DAT FRAME
    data_scaled = pd.DataFrame(data_transf, columns = x.columns)
    print(scaler)
    return data_scaled, optimus_prime

#Test the metric of the model with the testing results
def test_model_metrics(fitmodel, test_x,test_y):
    #Make predictions with the model and the new data set
    my_predictions = fitmodel.predict(test_x)
    #Reverse the log transform.
    my_predictions = np.exp(my_predictions)
    test_y = np.exp(test_y)
    #check results
    MAE =  mean_absolute_error(test_y,my_predictions)
    MSE = mean_squared_error(test_y,my_predictions)
    RMSE = np.sqrt(MSE)
    R2 = r2_score(test_y,my_predictions)
    MPE, ind_perc_errors = mean_absolute_percentage_error(np.asarray(test_y), my_predictions)
    
    
    MAE = "%6.2f" % MAE
    MSE = "%6.2f" % MSE
    RMSE = "%6.2f" % RMSE
    R2 = "%4.2f" % R2
    MPE = "%4.2f" % round(MPE, 4)
    
    
    return my_predictions, MAE, MSE, RMSE, R2, MPE

#Save the model info and metrics into a database
def save_model(df_, model_, scaler_,mae_,mse_,mrse_,r2_,mpe_, desc_):
    #create new df with new data
    datatoadd = pd.DataFrame(np.array([[(model_), (scaler_),(mae_),(mse_),(mrse_),(r2_),(mpe_),(desc_)]]), columns = df_.columns)
    #append both dataframes
    new_df = pd.concat([df_, datatoadd])
    return new_df

def save_model_intodb(model,scaler,mae, mse, mrse, r2, mpe, desr):
    new_df = save_model(trained_saved_models,str(model),str(scaler),mae, mse, mrse, r2, mpe, desr)
    return new_df

# %% [markdown]
# ### TRAIN AND TEST FUNCTIONS

# %%
#DEFINITION TO TRAIN, TEST, AND THEN SAVE RESULTS OF THE MODEL
def train_model(x,y, model,scaler):
    #CLEAN DATA
    x = cleaning_data_0(x)
    #CREATE DICTIONARY
    x, avg_dict, hex_dict = average_prices_hex_train(x,y)
    #apply the dictionary
    #x = average_prices_hex_test(x,avg_dict)
    #final cleaning
    x = final_clean(x, list_to_drop)
    #SCALE DATA AND SAVE THE SCALER
    scaled_data, optimusprime = scale_data(x, scaler)
    #FIT THE SCALED DATA INTO THE MODEL
    fit_model = model.fit(scaled_data, y)
    return x,fit_model, optimusprime,avg_dict, hex_dict

#DEFINITION TO TEST THE MODELS WE USED
def test_model(xtest, ytest, testing_model, trained_scaler, diction, hex_dict):
    #CLEAN DATA
    xtest = cleaning_data_0(xtest)
    #APPLY DICTIONARY
    xtest = average_prices_hex_test(xtest,diction,hex_dict )
    #final cleaning
    xtest = final_clean(xtest,list_to_drop)
    #Scale the test data with the trained scaler
    xtest = trained_scaler.transform(xtest)
    #TEST THE MODEL RESULTS
    _my_predictions, mae, mse, mrse, r2, mpe = test_model_metrics(testing_model,xtest,ytest)
    #RESPRESENT THE DATA
    print ("MAE: " + mae + " MSE: " + mse +" MRSE: " + mrse +" R2: "+ r2 +" MPE: "+ mpe)
    
    fig, ax = plt.subplots()

    ax.scatter(np.exp(ytest), _my_predictions)
    ax.plot([np.exp(ytest).min(), np.exp(ytest).max()], [np.exp(ytest).min(),np.exp(ytest).max()], 'k--', lw=4)
    ax.set_xlabel('Measured')
    ax.set_ylabel('Predicted')
    
    sns.scatterplot(y = _my_predictions, x = np.exp(ytest))
    return xtest,mae, mse, mrse, r2, mpe

# %% [markdown]
# ### TRAINING AND TESTING ZONE

# %% [markdown]
# #### Create variables to store models and dictionaries

# %%
## DATA FRAME WITH THE RATES AND THE MODEL DATA WE USED
trained_saved_models = pd.read_csv(r'C:\Users\urgpa\OneDrive\Escritorio\Documentos\RELHACKERS\LEWORK\DAY4_0\LAB\quijoman\data\model_results.xls')
## DICTIONARY WITH THE AVERAGE PRICES PER ZONE
avg_dict = {}

# %% [markdown]
# #### Do the train test split

# %%
y_clean = np.log(data["price"])# data['price']
X_clean = data.drop(['price'],axis=1)

#df_train["LogPrice"] = np.log(df_train["SalePrice"])


X_train, X_test, y_train, y_test = train_test_split(X_clean, y_clean, test_size=0.3, random_state=100)

# %% [markdown]
# #### Select dropped columns

# %%
list_to_drop = ['year_sold','sqft_living15','sqft_lot15','date','month_sold','condition', 'yr_built','bathrooms','waterfront']
list_to_drop
# Out:
# ['year_sold',
#  'sqft_living15',
#  'sqft_lot15',
#  'date',
#  'month_sold',
#  'condition',
#  'yr_built',
#  'bathrooms',
#  'waterfront']

# %% [markdown]
# #### Select model characteristics

# %% [markdown]
# Tried models:
#
#     LinearRegression()
#     KNeighborsRegressor(n_neighbors=5)
#     LassoLars(alpha=.1)
#     make_pipeline(PolynomialFeatures(2),LinearRegression())
#     SGDClassifier(loss="hinge", penalty="l2", max_iter=5)
#     RandomForestRegressor(random_state=100)
#     SGDRegressor(max_iter=1000, tol=1e-3)
#     XGBRegressor(learning_rate=0.01,n_estimators=20000,max_depth=3, min_child_weight=0,gamma=0, subsample=0.7,
#                                      colsample_bytree=0.7,
#                                      objective='reg:linear', nthread=-1,
#                                      scale_pos_weight=1, seed=27,
#                                      reg_alpha=0.006)
#
#     ensemble.GradientBoostingRegressor(**params)
#     params = {'n_estimators': 20000, 'max_depth': 5, 'min_samples_split': 2,
#           'learning_rate': 0.05, 'loss': 'ls' , 'max_features' : 2}
#           {'learning_rate': 0.15 , 'loss': 'huber', 'n_estimators':500, 'max_features':15}
#
# Tried Scalers:
#
#     MinMaxScaler, StandardScaler, PowerTransformer, QuantileTransformer, RobustScaler, MaxAbsScaler

# %%
mod = make_pipeline(PolynomialFeatures(2),LinearRegression())
sca = PowerTransformer()

# %% [markdown]
# #### Train a model with the train_data

# %%
trained_df ,model_temp,scaler_temp, dictionary, hex3_dict = train_model(X_train, y_train, mod, sca)
# Out:
# PowerTransformer()

# %% [markdown]
# #### Test the model and see the results

# %%
_xtest,_mae, _mse, _mrse, _r2, _mpe = test_model(X_test, y_test,model_temp, scaler_temp, dictionary, hex3_dict)
# Out:
# MAE: 98657.65 MSE: 32998226172.78 MRSE: 181654.14 R2: 0.77 MPE: 18.05

# %% [markdown]
# #### Add a description to the model

# %%
descrp = "LOG TRANSFORM PRICE  hex res: 6 \ FINALYrearrangin the dictionary \ ".join(list_to_drop)

# %% [markdown]
# #### Save the model

# %%
trained_saved_models = save_model_intodb(model_temp,scaler_temp,_mae, _mse, _mrse, _r2, _mpe, descrp)
trained_saved_models.head(60)
# Out:
#                                                Model            Transformer  \
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...         MinMaxScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...     PowerTransformer()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...         MaxAbsScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...  QuantileTransformer()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...           Normalizer()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0                              KNeighborsRegressor()       StandardScaler()
# 0                              KNeighborsRegressor()       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...         MinMaxScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0                              KNeighborsRegressor()       StandardScaler()
# 0                              KNeighborsRegressor()       StandardScaler()
# 0                KNeighborsRegressor(n_neighbors=12)       StandardScaler()
# 0                KNeighborsRegressor(n_neighbors=12)       StandardScaler()
# 0                KNeighborsRegressor(n_neighbors=12)       StandardScaler()
# 0                KNeighborsRegressor(n_neighbors=12)       StandardScaler()
# 0                          SGDClassifier(max_iter=5)       StandardScaler()
# 0   TweedieRegressor(alpha=0.5, link='log', power=1)       StandardScaler()
# 0            RandomForestRegressor(random_state=100)       StandardScaler()
# 0            RandomForestRegressor(random_state=100)         MinMaxScaler()
# 0                                    BayesianRidge()         MinMaxScaler()
# 0           SGDRegressor(fit_intercept=False, tol=1)         MinMaxScaler()
# 0  RandomForestRegressor(criterion='mae', random_...         MinMaxScaler()
# 0  RandomForestRegressor(min_samples_split=4, ran...       StandardScaler()
# 0                KNeighborsRegressor(n_neighbors=24)       StandardScaler()
# 0                KNeighborsRegressor(n_neighbors=16)       StandardScaler()
# 0                 KNeighborsRegressor(n_neighbors=8)       StandardScaler()
# 0                 KNeighborsRegressor(n_neighbors=6)       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...       StandardScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...         MaxAbsScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.05, ...         MaxAbsScaler()
# 0  Pipeline(steps=[('polynomialfeatures', Polynom...         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.05, ...         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.05, ...         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.75, ...         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.5, l...         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.25, ...         MaxAbsScaler()
# 0            GradientBoostingRegressor(loss='huber')         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.05, ...         MaxAbsScaler()
# 0      GradientBoostingRegressor(learning_rate=0.25)         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.25, ...         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.25, ...         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.25, ...         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.2, l...         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.15, ...         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.15, ...         MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.15, ...       StandardScaler()
#
#          MAE              MSE       MRSE     R2   MPE%  \
# 0  128818.98   38574459220.93  196403.82   0.74  26.80
# 0  131854.13   47311925351.98  217513.05   0.68  26.97
# 0  128814.87   38570983930.55  196394.97   0.74  26.77
# 0  139580.93   58714063040.10  242309.85   0.60  28.48
# 0  128250.32   38116712313.47  195235.02   0.74  26.73
# 0  142300.34   58309519672.18  241473.64   0.60  28.60
# 0  364753.17  316327830323.26  562430.29  -1.16  86.51
# 0  212059.40  100541345965.25  317082.55   0.31  45.87
# 0  170694.29   74600493619.71  273130.91   0.49  34.72
# 0  153900.54   74973525657.73  273812.94   0.49  28.11
# 0  153900.54   74973525657.73  273812.94   0.49  28.11
# 0  154108.52   72442041010.07  269150.59   0.51  29.52
# 0  154806.96   73879238883.61  271807.36   0.50  31.71
# 0  142300.34   58309519672.18  241473.64   0.60  28.60
# 0  141672.31   47373268018.78  217654.01   0.68  28.50
# 0  143423.14   48421258375.60  220048.31   0.67  28.65
# 0  143423.14   48421258375.60  220048.31   0.67  28.65
# 0  143423.14   48421258375.60  220048.31   0.67  28.65
# 0  120181.06   34922645053.73  186876.02   0.76  24.61
# 0  120181.07   34922681594.65  186876.11   0.76  24.61
# 0  107963.85   40119541929.46  200298.63   0.73  20.15
# 0  107963.85   40119541929.46  200298.63   0.73  20.15
# 0  105471.11   41348750303.09  203343.92   0.72  19.72
# 0  105471.11   41348750303.09  203343.92   0.72  19.72
# 0  141066.74   56069442478.89  236789.87   0.62  27.49
# 0  103311.17   41067463447.46  202651.09   0.72  19.62
# 0  207148.01  137726075506.06  371114.64   0.06  36.63
# 0  114709.79   34688116114.92  186247.46   0.76  21.98
# 0   82322.90   25812585270.08  160662.96   0.82  15.51
# 0   82460.01   25773436752.62  160541.07   0.82  15.52
# 0  134571.54   50238546626.71  224139.57   0.66  27.37
# 0  143103.75   54544674614.71  233548.01   0.63  29.80
# 0   83482.73   25711374548.83  160347.67   0.82  15.73
# 0   83482.73   25711374548.83  160347.67   0.82  15.73
# 0  105174.11   42933237400.33  207203.37   0.71  20.09
# 0  104014.71   41091153916.42  202709.53   0.72  19.85
# 0  103624.91   39387119795.49  198461.88   0.73  19.59
# 0  104804.76   39499293114.37  198744.29   0.73  19.77
# 0   97123.33   28285367852.58  168182.54   0.81  18.71
# 0   98199.97   31414374232.11  177241.01   0.79  17.90
# 0  102109.54   34484986115.24  185701.34   0.76  18.49
# 0  102109.52   34484895616.89  185701.09   0.76  18.49
# 0   75207.28   24410191638.08  156237.61   0.83  13.47
# 0   78290.97   23620596712.26  153689.94   0.84  14.33
# 0   83094.66   27119065602.47  164678.67   0.81  15.02
# 0   78965.34   24739912834.11  157289.26   0.83  14.26
# 0   78875.80   23739712375.42  154076.97   0.84  14.47
# 0   86501.84   29269715594.37  171083.94   0.80  15.75
# 0   76602.99   21651593016.50  147144.80   0.85  14.01
# 0   74364.52   20685428806.38  143824.30   0.86  13.51
# 0   80179.63   27611546327.31  166167.22   0.81  14.24
# 0   87554.00   37970771129.47  194860.90   0.74  15.27
# 0   75757.92   22263959181.75  149211.12   0.85  13.68
# 0   71957.69   20261461023.31  142342.76   0.86  13.12
# 0   72794.54   21949738729.17  148154.44   0.85  13.22
# 0   74024.25   21195946339.14  145588.28   0.86  13.36
# 0   72635.58   20471243972.68  143077.75   0.86  13.16
# 0   71435.57   21231309485.16  145709.68   0.85  12.98
# 0   72649.41   20477996816.40  143101.35   0.86  13.19
# 0   71640.93   20974754036.08  144826.63   0.86  12.95
#
#                                                Descr
# 0   hex res: 2 'zipcode', 'year_sold', \ 'lat', \...
# 0   hex res: 2 'zipcode', 'year_sold', \ 'lat', \...
# 0   hex res: 2 'zipcode', 'year_sold', \ 'lat', \...
# 0   hex res: 2 'zipcode', 'year_sold', \ 'lat', \...
# 0   hex res: 2 'zipcode', 'year_sold', \ 'lat', \...
# 0   hex res: 6 'zipcode', 'year_sold', \ 'lat', \...
# 0   hex res: 12 'zipcode', 'year_sold', \ 'lat', ...
# 0   hex res: 8 'zipcode', 'year_sold', \ 'lat', \...
# 0   hex res: 7 'zipcode', 'year_sold', \ 'lat', \...
# 0   hex res: 5 'zipcode', 'year_sold', \ 'lat', \...
# 0   hex res: 5 'zipcode', 'year_sold', \ 'lat', \...
# 0   hex res: 5 'zipcode', 'year_sold', \ 'lat', \...
# 0   hex res: 6 'zipcode', 'year_sold', \ 'lat', \...
# 0   hex res: 6 \ rearrangin the dictionary 'zipco...
# 0   hex res: 6 \ FINALYrearrangin the dictionary ...
# 0   hex res: 6 \ FINALYrearrangin the dictionary ...
# 0  zipcode hex res: 6 \ FINALYrearrangin the dict...
# 0  zipcode hex res: 6 \ FINALYrearrangin the dict...
# 0  zipcode hex res: 6 \ FINALYrearrangin the dict...
# 0  zipcode hex res: 6 \ FINALYrearrangin the dict...
# 0  zipcode hex res: 6 \ FINALYrearrangin the dict...
# 0  zipcode hex res: 6 \ FINALYrearrangin the dict...
# 0  zipcode hex res: 6 \ FINALYrearrangin the dict...
# 0  zipcode hex res: 6 \ FINALYrearrangin the dict...
# 0  zipcode hex res: 6 \ FINALYrearrangin the dict...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_sold hex res: 6 \ FINALYrearrangin the di...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...

# %%
trained_saved_models.sort_values(['R2','MPE%'], ascending=False).head(15)
# Out:
#                                                Model         Transformer  \
# 0  GradientBoostingRegressor(learning_rate=0.15, ...  PowerTransformer()
# 0  GradientBoostingRegressor(learning_rate=0.25, ...      MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.25, ...      MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.15, ...      MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.2, l...      MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.25, ...      MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.15, ...    StandardScaler()
# 0  GradientBoostingRegressor(learning_rate=0.5, l...      MaxAbsScaler()
# 0      GradientBoostingRegressor(learning_rate=0.25)      MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.25, ...      MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.15, ...      MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.15, ...      MinMaxScaler()
# 0  GradientBoostingRegressor(learning_rate=0.05, ...      MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.05, ...      MaxAbsScaler()
# 0  GradientBoostingRegressor(learning_rate=0.05, ...      MaxAbsScaler()
#
#         MAE             MSE       MRSE    R2   MPE%  \
# 0  75372.84  21029058853.10  145014.00  0.86  13.62
# 0  74364.52  20685428806.38  143824.30  0.86  13.51
# 0  74024.25  21195946339.14  145588.28  0.86  13.36
# 0  72649.41  20477996816.40  143101.35  0.86  13.19
# 0  72635.58  20471243972.68  143077.75  0.86  13.16
# 0  71957.69  20261461023.31  142342.76  0.86  13.12
# 0  71640.93  20974754036.08  144826.63  0.86  12.95
# 0  76602.99  21651593016.50  147144.80  0.85  14.01
# 0  75757.92  22263959181.75  149211.12  0.85  13.68
# 0  72794.54  21949738729.17  148154.44  0.85  13.22
# 0  71435.57  21231309485.16  145709.68  0.85  12.98
# 0  71273.36  21326291171.10  146035.24  0.85  12.91
# 0  78875.80  23739712375.42  154076.97  0.84  14.47
# 0  78290.97  23620596712.26  153689.94  0.84  14.33
# 0  78965.34  24739912834.11  157289.26  0.83  14.26
#
#                                                Descr
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 0  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...

# %% [markdown]
# #### Save all model results

# %%
trained_saved_models.to_csv(r'C:\Users\urgpa\OneDrive\Escritorio\Documentos\RELHACKERS\LEWORK\DAY4_0\LAB\quijoman\data\model_results.xls', index = False)

# %% [markdown]
# # EXTRA CONTENT

# %%
a = pd.read_csv(r'C:\Users\urgpa\OneDrive\Escritorio\Documentos\RELHACKERS\LEWORK\DAY4_0\LAB\quijoman\data\model_results.xls')

# %%
a
# Out:
#                                                 Model            Transformer  \
# 0   Pipeline(steps=[('polynomialfeatures', Polynom...         MinMaxScaler()
# 1   Pipeline(steps=[('polynomialfeatures', Polynom...     PowerTransformer()
# 2   Pipeline(steps=[('polynomialfeatures', Polynom...         MaxAbsScaler()
# 3   Pipeline(steps=[('polynomialfeatures', Polynom...  QuantileTransformer()
# 4   Pipeline(steps=[('polynomialfeatures', Polynom...           Normalizer()
# ..                                                ...                    ...
# 58  GradientBoostingRegressor(learning_rate=0.15, ...         MaxAbsScaler()
# 59  GradientBoostingRegressor(learning_rate=0.15, ...       StandardScaler()
# 60  GradientBoostingRegressor(learning_rate=0.15, ...         MinMaxScaler()
# 61  GradientBoostingRegressor(learning_rate=0.15, ...     PowerTransformer()
# 62  Pipeline(steps=[('polynomialfeatures', Polynom...     PowerTransformer()
#
#           MAE           MSE       MRSE    R2   MPE%  \
# 0   128818.98  3.857446e+10  196403.82  0.74  26.80
# 1   131854.13  4.731193e+10  217513.05  0.68  26.97
# 2   128814.87  3.857098e+10  196394.97  0.74  26.77
# 3   139580.93  5.871406e+10  242309.85  0.60  28.48
# 4   128250.32  3.811671e+10  195235.02  0.74  26.73
# ..        ...           ...        ...   ...    ...
# 58   72649.41  2.047800e+10  143101.35  0.86  13.19
# 59   71640.93  2.097475e+10  144826.63  0.86  12.95
# 60   71273.36  2.132629e+10  146035.24  0.85  12.91
# 61   75372.84  2.102906e+10  145014.00  0.86  13.62
# 62   98657.65  3.299823e+10  181654.14  0.77  18.05
#
#                                                 Descr
# 0    hex res: 2 'zipcode', 'year_sold', \ 'lat', \...
# 1    hex res: 2 'zipcode', 'year_sold', \ 'lat', \...
# 2    hex res: 2 'zipcode', 'year_sold', \ 'lat', \...
# 3    hex res: 2 'zipcode', 'year_sold', \ 'lat', \...
# 4    hex res: 2 'zipcode', 'year_sold', \ 'lat', \...
# ..                                                ...
# 58  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 59  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 60  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 61  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
# 62  year_soldLOG TRANSFORM PRICE  hex res: 6 \ FIN...
#
# [63 rows x 8 columns]

# %% [markdown]
# #### See descritptions

# %%
print(trained_saved_models.Descr[0])
# Out:
#  hex res: 2 'zipcode', 'year_sold', \ 'lat', \ 'long', \ 'sqft_living15', \ 'date', \ 'month_sold', \ 'condition', \ 'yr_built', \ 'sqft_living',\ 'sqft_lot',\ 'bathrooms',\ 'waterfront'

# %%
trained_df.head(20)
# Out:
#             bedrooms  sqft_living  sqft_lot  floors  view  grade  sqft_above  \
# id
# 7199320600         3         2030      7350       1     0      7        1190
# 2402100675         3         2050      6000       2     0      7        1550
# 9264950940         3         2060      7458       2     0      9        2060
# 8108600464         3         2150     30476       2     0      7        2150
# 322059049          2          820    288367       1     0      6         820
# 5316100255         2         2330      3600       2     0     10        1870
# 9137101696         3         1660      1692       3     0      7        1610
# 3298300140         3         1210      6650       1     0      6        1210
# 6117900120         3         3320     15022       2     0     10        3320
# 3293700521         3         1820      8028       1     0      7        1220
# 3735900545         3         1560      4080       2     0      7        1560
# 1233100720         3          860      9403       1     0      6         860
# 1561900330         4         2350      9952       1     0      9        1650
# 5458300580         2         1200      1867       1     0      7         600
# 3541600235         3         1900     10225       1     0      8        1220
# 7891600590         3         1240      5000       1     2      7        1240
# 7140200380         3         1910      8050       1     0      7        1000
# 6411600045         4         2240      9385       2     0      8        2240
# 3760500435         3         2730     11936       2     2      8        1530
# 4137070830         3         2190      7904       2     0      8        2190
#
#             sqft_basement  yr_renovated  zipcode      lat     long  house_age  \
# id
# 7199320600              1             0    98052  47.6939 -122.126         43
# 2402100675              1             0    98103  47.6873 -122.332        110
# 9264950940              0             0    98023  47.3045 -122.351         31
# 8108600464              0             0    98188  47.4605 -122.277         29
# 322059049               0             1    98042  47.4196 -122.165         90
# 5316100255              1             1    98112  47.6316 -122.282         93
# 9137101696              1             0    98115  47.6801 -122.322         15
# 3298300140              0             0    98008  47.6214 -122.120         61
# 6117900120              0             0    98166  47.4290 -122.341         31
# 3293700521              1             0    98133  47.7466 -122.355         40
# 3735900545              0             1    98115  47.6892 -122.319         97
# 1233100720              0             1    98033  47.6815 -122.173         78
# 1561900330              1             0    98031  47.4194 -122.211         31
# 5458300580              1             1    98109  47.6270 -122.345         96
# 3541600235              1             0    98166  47.4781 -122.357         57
# 7891600590              0             0    98106  47.5659 -122.360         56
# 7140200380              1             0    98030  47.3700 -122.170         40
# 6411600045              0             0    98133  47.7125 -122.332         29
# 3760500435              1             0    98034  47.6987 -122.231         42
# 4137070830              0             0    98092  47.2617 -122.210         25
#
#             hex_3  avg_price  sqft_living_price  sqft_lot_price  \
# id
# 7199320600      0  13.962828         145.386018      526.397651
# 2402100675      1  13.916617         147.305917      431.139269
# 9264950940      2  13.836737         148.879029      538.999901
# 8108600464      3  13.703792         156.890879     2223.909969
# 322059049       4  13.550888          60.512639    21280.302474
# 5316100255      5  13.533891         172.160392      265.998889
# 9137101696      1  13.916617         119.281865      121.581274
# 3298300140      6  13.528464          89.441047      491.556166
# 6117900120      7  13.468483         246.501399     1115.344582
# 3293700521      8  13.442555         135.390927      597.207893
# 3735900545      1  13.916617         112.096210      293.174703
# 1233100720      9  13.436124          64.006553      699.829784
# 1561900330      4  13.550888         173.420366      734.416803
# 5458300580     10  13.423396          89.396156      139.085520
# 3541600235     11  13.402437         141.765259      762.920935
# 7891600590     12  13.398521          92.547529      373.175521
# 7140200380     13  13.359217         142.972450      602.580223
# 6411600045      8  13.442555         166.634988      698.155964
# 3760500435     14  13.342359         204.611487      894.594399
# 4137070830     15  13.337475         164.198999      592.615929
#
#             sqft_living15_price  sqft_lot15_price
# id
# 7199320600           139.656520        526.397651
# 2402100675           127.904650        287.426180
# 9264950940           179.233005        559.597243
# 8108600464           146.674729        788.103021
# 322059049            116.597523        601.731774
# 5316100255           217.971312        531.997779
# 9137101696            86.946419         88.383550
# 3298300140            73.179038        561.039293
# 6117900120           254.668614       1115.047593
# 3293700521           144.317802        825.735876
# 3735900545           136.527435        293.174703
# 1233100720           158.974414        968.210748
# 1561900330           180.061998        671.542696
# 5458300580           133.349266        165.457386
# 3541600235           138.034595        942.365908
# 7891600590            78.366860        373.175521
# 7140200380           133.241341        549.732815
# 6411600045           149.525145        669.515575
# 3760500435           210.607428        924.349256
# 4137070830           164.198999        574.996402

# %%
##Define a function that differentiates between 
##continuous and discrete variables
def diff_concr_discr_cat(_data):
    cat   = pd.DataFrame()
    discr = pd.DataFrame()
    cont  = pd.DataFrame()
    
    for i in _data.columns:
        if _data[i].dtype == 'object':
            cat[i] = _data[i]
        elif _data[i].dtype == 'int64':
            discr[i] = _data[i]
        elif _data[i].dtype == 'float64':
            cont[i] = _data[i]
            
    return cat, discr, cont


#we have a division between types of data. Cat is empty.
#trained_df['price'] = data['price']
df_cat, df_discr, df_cont = diff_concr_discr_cat(trained_df)

# %%
def corr_matrix(df):  
    corr_matrix=df.corr(method='pearson')  # default
    mask = np.zeros_like(corr_matrix)
    mask[np.triu_indices_from(mask)] = True
    fig, ax = plt.subplots(figsize=(10, 8))
    ax = sns.heatmap(corr_matrix,mask = mask, annot=True)
    plt.show()

# %%
def columns_vif(df, target, drop=[]):
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    temporary_vif_frame = df.drop(drop, axis=1)
    dropped_vif_frame = temporary_vif_frame.drop(target, axis=1)
    cols = dropped_vif_frame.columns
    temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_vif_frame)
    vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]
    for i in range(len(cols)):
        print(str(cols[i]) + "--------" + str(vif[i]))
    return temporary_vif_frame

# %%
trained_df['price'] = data['price']
columns_vif(trained_df, 'price',[] )
# Out:
# bedrooms--------21.9676400513567
# sqft_living--------17176.33987133218
# sqft_lot--------2898.556767539069
# floors--------15.958018485436549
# view--------1.3591935100104104
# grade--------149.17145759872764
# sqft_above--------92.34680867741507
# sqft_basement--------5.567889611035393
# yr_renovated--------1.1484208649190266
# zipcode--------1665499.0580945795
# lat--------144575.43558039799
# long--------1431203.4525154508
# house_age--------7.574767386315578
# hex_3--------24.493590962898363
# avg_price--------25926.68876138488
# sqft_living_price--------17074.89030892627
# sqft_lot_price--------2890.7844487453845
# sqft_living15_price--------27.121864629878722
# sqft_lot15_price--------2.4625608988488707
#             bedrooms  sqft_living  sqft_lot  floors  view  grade  sqft_above  \
# id
# 7199320600         3         2030      7350       1     0      7        1190
# 2402100675         3         2050      6000       2     0      7        1550
# 9264950940         3         2060      7458       2     0      9        2060
# 8108600464         3         2150     30476       2     0      7        2150
# 322059049          2          820    288367       1     0      6         820
# ...              ...          ...       ...     ...   ...    ...         ...
# 8001450170         3         1840     16679       1     0      8        1840
# 1531000030         4         3450     39683       2     0     10        3450
# 1042500013         3         1650      9936       1     0      7        1090
# 5153200666         3         1900     18000       1     0      7        1280
# 3342101937         5         3460      5400       2     0     10        2830
#
#             sqft_basement  yr_renovated  zipcode      lat     long  house_age  \
# id
# 7199320600              1             0    98052  47.6939 -122.126         43
# 2402100675              1             0    98103  47.6873 -122.332        110
# 9264950940              0             0    98023  47.3045 -122.351         31
# 8108600464              0             0    98188  47.4605 -122.277         29
# 322059049               0             1    98042  47.4196 -122.165         90
# ...                   ...           ...      ...      ...      ...        ...
# 8001450170              0             0    98001  47.3207 -122.275         31
# 1531000030              0             0    98010  47.3420 -122.025         18
# 1042500013              1             0    98003  47.3285 -122.328         53
# 5153200666              1             0    98023  47.3251 -122.354         52
# 3342101937              1             0    98056  47.5201 -122.204          8
#
#             hex_3  avg_price  sqft_living_price  sqft_lot_price  \
# id
# 7199320600      0  13.962828         145.386018      526.397651
# 2402100675      1  13.916617         147.305917      431.139269
# 9264950940      2  13.836737         148.879029      538.999901
# 8108600464      3  13.703792         156.890879     2223.909969
# 322059049       4  13.550888          60.512639    21280.302474
# ...           ...        ...                ...             ...
# 8001450170     46  13.048546         141.011881     1278.226717
# 1531000030     61  12.929850         266.824443     3069.099814
# 1042500013      2  13.836737         119.247766      718.088364
# 5153200666      2  13.836737         137.315609     1300.884717
# 3342101937     23  13.281472         260.513292      406.581438
#
#             sqft_living15_price  sqft_lot15_price  price
# id
# 7199320600           139.656520        526.397651    NaN
# 2402100675           127.904650        287.426180    NaN
# 9264950940           179.233005        559.597243    NaN
# 8108600464           146.674729        788.103021    NaN
# 322059049            116.597523        601.731774    NaN
# ...                         ...               ...    ...
# 8001450170           146.376463       1193.313041    NaN
# 1531000030           259.090401       3074.281622    NaN
# 1042500013           112.743342        714.763881    NaN
# 5153200666           138.761037       1084.070598    NaN
# 3342101937           142.303503        406.581438    NaN
#
# [15117 rows x 20 columns]

# %%
corr_matrix(df_cont)

# %%
corr_matrix(df_discr)
