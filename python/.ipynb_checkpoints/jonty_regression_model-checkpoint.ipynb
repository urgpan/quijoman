# %% [markdown]
# **Objective**
#
# Your job is to build a model that will predict the price of a house based on features provided in the dataset. Senior management also wants to explore the characteristics of the houses using some business intelligence tools. One of those parameters includes understanding which factors are responsible for higher property value - $650K and above.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

# %%
data = pd.read_excel("C:/Users/jw156/Ironhack/Day20/data_mid_bootcamp_project_regression/regression_data.xls")

# %%
data.shape
# Out:
# (21597, 21)

# %%
data.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')

# %%
data.count()
# Out:
# id               21597
# date             21597
# bedrooms         21597
# bathrooms        21597
# sqft_living      21597
# sqft_lot         21597
# floors           21597
# waterfront       21597
# view             21597
# condition        21597
# grade            21597
# sqft_above       21597
# sqft_basement    21597
# yr_built         21597
# yr_renovated     21597
# zipcode          21597
# lat              21597
# long             21597
# sqft_living15    21597
# sqft_lot15       21597
# price            21597
# dtype: int64

# %%
data.isna().sum()
# Out:
# id               0
# date             0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# price            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  datetime64[ns]
#  2   bedrooms       21597 non-null  int64
#  3   bathrooms      21597 non-null  float64
#  4   sqft_living    21597 non-null  int64
#  5   sqft_lot       21597 non-null  int64
#  6   floors         21597 non-null  float64
#  7   waterfront     21597 non-null  int64
#  8   view           21597 non-null  int64
#  9   condition      21597 non-null  int64
#  10  grade          21597 non-null  int64
#  11  sqft_above     21597 non-null  int64
#  12  sqft_basement  21597 non-null  int64
#  13  yr_built       21597 non-null  int64
#  14  yr_renovated   21597 non-null  int64
#  15  zipcode        21597 non-null  int64
#  16  lat            21597 non-null  float64
#  17  long           21597 non-null  float64
#  18  sqft_living15  21597 non-null  int64
#  19  sqft_lot15     21597 non-null  int64
#  20  price          21597 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(16)
# memory usage: 3.5 MB

# %%
data.nunique()
# Out:
# id               21420
# date               372
# bedrooms            12
# bathrooms           29
# sqft_living       1034
# sqft_lot          9776
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               11
# sqft_above         942
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5033
# long               751
# sqft_living15      777
# sqft_lot15        8682
# price             3622
# dtype: int64

# %%
def get_months(x):
    x = x.strftime("%m")
    return int(x)

def get_years(x):
    x = x.strftime("%Y")
    return int(x)

# %%
data['month_sold'] = list(map(get_months, data['date']))
data['year_sold'] = list(map(get_years, data['date']))

# %%
data['bathrooms'] = list(map(round, data['bathrooms']))

# %%
data.nunique()
# Out:
# id               21420
# date               372
# bedrooms            12
# bathrooms            9
# sqft_living       1034
# sqft_lot          9776
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               11
# sqft_above         942
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5033
# long               751
# sqft_living15      777
# sqft_lot15        8682
# price             3622
# month_sold          12
# year_sold            2
# dtype: int64

# %%
data.month_sold.unique
# Out:
# <bound method Series.unique of 0        10
# 1        12
# 2         2
# 3        12
# 4         2
#          ..
# 21592     5
# 21593     2
# 21594     6
# 21595     1
# 21596    10
# Name: month_sold, Length: 21597, dtype: int64>

# %%
data = data.drop(['date'], axis=1)

# %%
data = train[train['Sex'] == 'female']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-b4a74ef0159a> in <module>
# ----> 1 data = train[train['Sex'] == 'female']
#
# NameError: name 'train' is not defined

# %% [markdown]
# ### Checking for Multi-Collinearity

# %%
data = data.drop(['id'], axis=1)
corr=data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col0,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow1_col1,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow2_col2,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow3_col3,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow4_col4,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow5_col5,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow6_col6,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow7_col7,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow8_col8,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow9_col9,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow10_col10,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow11_col11,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow12_col12,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow13_col13,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow14_col14,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow15_col15,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow16_col16,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow17_col17,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow18_col18,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow19_col19,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow20_col20{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col1{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col2,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow9_col1{
#             background-color:  #f6bda2;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col3,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow3_col6,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow10_col17,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow19_col14,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow20_col2{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col4,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow15_col17{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col5,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow7_col8{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col6,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow7_col16{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col7,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow19_col7{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col8,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow1_col15,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow18_col10{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col9{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col10,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col19,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow4_col15,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow6_col16,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow6_col20,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow11_col20,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow13_col19,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow13_col20,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow15_col20,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow16_col19,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow17_col19,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow17_col20,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow18_col6,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow18_col20{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col11,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow5_col13{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col12,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow16_col7{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col13,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow5_col9,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow5_col10,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow17_col7{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col14,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow4_col17,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow8_col5,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow10_col5,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow20_col3{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col15,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow1_col19,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow3_col20,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow5_col6,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow5_col19,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow8_col0,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow8_col19,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow9_col19,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow10_col19{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col16,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow17_col15{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col17,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow5_col17,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow9_col10,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow12_col14{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col18{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow0_col20,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow10_col20,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow11_col2,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow16_col4,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow18_col19{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow1_col0{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow1_col2,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow17_col3,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow18_col2{
#             background-color:  #f4987a;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow1_col3,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow6_col17,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow8_col12,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow9_col13,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow18_col3,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow19_col12{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow1_col4{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow1_col5,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow11_col18,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow20_col1,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow20_col14{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow1_col6,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow3_col7,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow5_col12,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow15_col1,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow17_col8,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow19_col11{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow1_col7,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow8_col3,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow12_col16,#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow19_col9{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_42d08f87_6ac2_11eb_8e24_a4b1c1f4aebarow1_col8{
#             background-color:  #f7bca1;
#             color:  #000000;
#         }#T_42d08f87_6ac

# %% [markdown]
# It appears that sqft_living, grade, sqft_above are correlated to the price. Additinally, some other points that are highly correlated:
# - sqft_above & sqft_living
# - sqft_living & bathrooms
# - grade & sqft_living
# - grade & sqft_above
# - grade & sqft_living15
# - sqft_above & living16

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
  
# the independent variables set 
X = data.drop(['price', 'id'], axis=1)
  
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 
  
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) 
                          for i in range(len(X.columns))] 
  
print(vif_data)
# Out:
# C:\Users\jw156\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#           feature           VIF
# 0        bedrooms  2.332084e+01
# 1       bathrooms  1.939988e+01
# 2     sqft_living           inf
# 3        sqft_lot  2.379757e+00
# 4          floors  1.642670e+01
# 5      waterfront  1.213430e+00
# 6            view  1.569358e+00
# 7       condition  3.534399e+01
# 8           grade  1.494563e+02
# 9      sqft_above           inf
# 10  sqft_basement           inf
# 11       yr_built  1.013766e+04
# 12   yr_renovated  1.193072e+00
# 13        zipcode  5.220221e+06
# 14            lat  1.393068e+05
# 15           long  1.380522e+06
# 16  sqft_living15  2.806022e+01
# 17     sqft_lot15  2.599348e+00
# 18     month_sold  6.204506e+00
# 19      year_sold  4.176226e+06

# %% [markdown]
# **Correlation is highly correlated & needs to be transformed**

# %% [markdown]
# **Step_1**: drop 1 highly correlated feature highly correlated:
#  - drop zipcode
#  - year_sold

# %%
X = data.drop(['zipcode', 'year_sold'], axis=1)
  
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 
  
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) 
                          for i in range(len(X.columns))] 
  
print(vif_data)
# Out:
# C:\Users\jw156\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#           feature           VIF
# 0        bedrooms  2.360396e+01
# 1       bathrooms  1.955527e+01
# 2     sqft_living           inf
# 3        sqft_lot  2.363338e+00
# 4          floors  1.577219e+01
# 5      waterfront  1.276911e+00
# 6            view  1.594375e+00
# 7       condition  3.487381e+01
# 8           grade  1.596811e+02
# 9      sqft_above           inf
# 10  sqft_basement           inf
# 11       yr_built  8.756777e+03
# 12   yr_renovated  1.183992e+00
# 13            lat  1.325736e+05
# 14           long  1.400702e+05
# 15  sqft_living15  2.700443e+01
# 16     sqft_lot15  2.586316e+00
# 17          price  1.021386e+01
# 18     month_sold  5.475117e+00

# %% [markdown]
# **Step_2**: transform highly correlated feature:
#  - month_sold to season_sold
#  - yr_built to house_age

# %%
def season_sold(x):
    if x == '3' or x == '4' or x == '5':
        return 'Spring'
    elif x == '6' or x == '7' or x == '8':
        return 'Summer'
    if x == '9' or x == '10' or x == '1':
        return 'Autumn'
    else:
        return 'Winter'

# %% [markdown]
# # Graphs

# %%
graph_data = data.drop(['id'], axis=1)

# %%
for col in graph_data.columns:
    sns.distplot(graph_data[col], kde=False);
    plt.show()
# Out:
# C:\Users\jw156\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
intz = data.select_dtypes(include=np.int64)
intz = intz.drop(['id'], axis=1)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from shapely.geometry import Point
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-728d012ab5d9> in <module>
# ----> 1 import geopandas as gpd
#       2 import matplotlib.pyplot as plt
#       3 import contextily as ctx
#       4 from shapely.geometry import Point
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
for col in intz.columns:
    sns.countplot(x=col, data=intz)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-2628e4627050> in <module>
#       1 for col in intz.columns:
#       2     sns.countplot(x=col, data=intz)
# ----> 3     plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         FigureCanvasAgg.draw(self)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1163
#    1164         ticks_to_draw = self._update_ticks()
# -> 1165         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1166                                                                 renderer)
#    1167
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     898
#     899         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 900             bbox, info, descent = self._get_layout(self._renderer)
#     901             x, y = self.get_unitless_position()
#     902             x, y = self.get_transform().transform((x, y))
#
# ~\Anaconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     291             clean_line, ismath = self._preprocess_math(line)
#     292             if clean_line:
# --> 293                 w, h, d = renderer.get_text_width_height_descent(
#     294                     clean_line, self._fontproperties, ismath=ismath)
#     295             else:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     235
#     236         flags = get_hinting_flag()
# --> 237         font = self._get_agg_font(prop)
#     238         font.set_text(s, 0.0, flags=flags)
#     239         w, h = font.get_width_height()  # width and height of unrotated string
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in _get_agg_font(self, prop)
#     270         Get the font for text instance t, caching for efficiency
#     271         """
# --> 272         fname = findfont(prop)
#     273         font = get_font(fname)
#     274
#
# ~\Anaconda3\lib\site-packages\matplotlib\font_manager.py in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1312             prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1313             rc_params)
# -> 1314         return os.path.realpath(filename)
#    1315
#    1316     @lru_cache()
#
# ~\Anaconda3\lib\ntpath.py in realpath(path)
#     662             # Ensure that the non-prefixed path resolves to the same path
#     663             try:
# --> 664                 if _getfinalpathname(spath) == path:
#     665                     path = spath
#     666             except OSError as ex:
#
# KeyboardInterrupt:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  datetime64[ns]
#  2   bedrooms       21597 non-null  int64
#  3   bathrooms      21597 non-null  float64
#  4   sqft_living    21597 non-null  int64
#  5   sqft_lot       21597 non-null  int64
#  6   floors         21597 non-null  float64
#  7   waterfront     21597 non-null  int64
#  8   view           21597 non-null  int64
#  9   condition      21597 non-null  int64
#  10  grade          21597 non-null  int64
#  11  sqft_above     21597 non-null  int64
#  12  sqft_basement  21597 non-null  int64
#  13  yr_built       21597 non-null  int64
#  14  yr_renovated   21597 non-null  int64
#  15  zipcode        21597 non-null  int64
#  16  lat            21597 non-null  float64
#  17  long           21597 non-null  float64
#  18  sqft_living15  21597 non-null  int64
#  19  sqft_lot15     21597 non-null  int64
#  20  price          21597 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(16)
# memory usage: 3.5 MB

# %%
data.describe()
# Out:
#                  id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  2.159700e+04
# mean   4.580474e+09      3.373200      2.115826   2080.321850  1.509941e+04
# std    2.876736e+09      0.926299      0.768984    918.106125  4.141264e+04
# min    1.000102e+06      1.000000      0.500000    370.000000  5.200000e+02
# 25%    2.123049e+09      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    3.904930e+09      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    7.308900e+09      4.000000      2.500000   2550.000000  1.068500e+04
# max    9.900000e+09     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21597.000000  21597.000000  21597.000000  21597.000000  21597.000000
# mean       1.494096      0.007547      0.234292      3.409825      7.657915
# std        0.539683      0.086549      0.766390      0.650546      1.173200
# min        1.000000      0.000000      0.000000      1.000000      3.000000
# 25%        1.000000      0.000000      0.000000      3.000000      7.000000
# 50%        1.500000      0.000000      0.000000      3.000000      7.000000
# 75%        2.000000      0.000000      0.000000      4.000000      8.000000
# max        3.500000      1.000000      4.000000      5.000000     13.000000
#
#          sqft_above  sqft_basement      yr_built  yr_renovated       zipcode  \
# count  21597.000000   21597.000000  21597.000000  21597.000000  21597.000000
# mean    1788.596842     291.725008   1970.999676     84.464787  98077.951845
# std      827.759761     442.667800     29.375234    401.821438     53.513072
# min      370.000000       0.000000   1900.000000      0.000000  98001.000000
# 25%     1190.000000       0.000000   1951.000000      0.000000  98033.000000
# 50%     1560.000000       0.000000   1975.000000      0.000000  98065.000000
# 75%     2210.000000     560.000000   1997.000000      0.000000  98118.000000
# max     9410.000000    4820.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15         price
# count  21597.000000  21597.000000   21597.000000   21597.000000  2.159700e+04
# mean      47.560093   -122.213982    1986.620318   12758.283512  5.402966e+05
# std        0.138552      0.140724     685.230472   27274.441950  3.673681e+05
# min       47.155900   -122.519000     399.000000     651.000000  7.800000e+04
# 25%       47.471100   -122.328000    1490.000000    5100.000000  3.220000e+05
# 50%       47.571800   -122.231000    1840.000000    7620.000000  4.500000e+05
# 75%       47.678000   -122.125000    2360.000000   10083.000000  6.450000e+05
# max       47.777600   -121.315000    6210.000000  871200.000000  7.700000e+06

# %%
BBox = ((data.long.min(),   data.long.max(),      
         data.lat.min(), data.lat.max()))

# %%
BBox
# Out:
# (-122.519, -121.315, 47.1559, 47.7776)

# %%
data.nunique()
# Out:
# id               21420
# date               372
# bedrooms            12
# bathrooms           29
# sqft_living       1034
# sqft_lot          9776
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               11
# sqft_above         942
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5033
# long               751
# sqft_living15      777
# sqft_lot15        8682
# price             3622
# dtype: int64

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cbook import dedent
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-31b4185f77bc> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from matplotlib.cbook import dedent
#
# ImportError: cannot import name 'dedent' from 'matplotlib.cbook' (C:\Users\jw156\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py)
