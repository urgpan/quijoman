# %% [markdown]
# **Objective**
#
# Your job is to build a model that will predict the price of a house based on features provided in the dataset. Senior management also wants to explore the characteristics of the houses using some business intelligence tools. One of those parameters includes understanding which factors are responsible for higher property value - $650K and above.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import math

# %%
data = pd.read_excel("C:/Users/jw156/Ironhack/Day20/data_mid_bootcamp_project_regression/regression_data.xls")

# %%
data.shape
# Out:
# (21597, 21)

# %%
data.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')

# %%
data.count()
# Out:
# id               21597
# date             21597
# bedrooms         21597
# bathrooms        21597
# sqft_living      21597
# sqft_lot         21597
# floors           21597
# waterfront       21597
# view             21597
# condition        21597
# grade            21597
# sqft_above       21597
# sqft_basement    21597
# yr_built         21597
# yr_renovated     21597
# zipcode          21597
# lat              21597
# long             21597
# sqft_living15    21597
# sqft_lot15       21597
# price            21597
# dtype: int64

# %%
data.isna().sum()
# Out:
# id               0
# date             0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# price            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  datetime64[ns]
#  2   bedrooms       21597 non-null  int64
#  3   bathrooms      21597 non-null  float64
#  4   sqft_living    21597 non-null  int64
#  5   sqft_lot       21597 non-null  int64
#  6   floors         21597 non-null  float64
#  7   waterfront     21597 non-null  int64
#  8   view           21597 non-null  int64
#  9   condition      21597 non-null  int64
#  10  grade          21597 non-null  int64
#  11  sqft_above     21597 non-null  int64
#  12  sqft_basement  21597 non-null  int64
#  13  yr_built       21597 non-null  int64
#  14  yr_renovated   21597 non-null  int64
#  15  zipcode        21597 non-null  int64
#  16  lat            21597 non-null  float64
#  17  long           21597 non-null  float64
#  18  sqft_living15  21597 non-null  int64
#  19  sqft_lot15     21597 non-null  int64
#  20  price          21597 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(16)
# memory usage: 3.5 MB

# %%
data.nunique()
# Out:
# id               21420
# date               372
# bedrooms            12
# bathrooms           29
# sqft_living       1034
# sqft_lot          9776
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               11
# sqft_above         942
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5033
# long               751
# sqft_living15      777
# sqft_lot15        8682
# price             3622
# dtype: int64

# %%
def get_months(x):
    x = x.strftime("%m")
    return int(x)

def get_years(x):
    x = x.strftime("%Y")
    return int(x)

def get_weekday(x):
    x = x.strftime("%w")
    return int(x)

def get_weekyear(x):
    x = x.strftime("%W")
    return int(x)

# %%
data['month_sold'] = list(map(get_months, data['date']))
data['year_sold'] = list(map(get_years, data['date']))

# %%
data['week_year_sold'] = data['date'].apply(get_weekyear)

# %%
data['week_day'] = data['date'].apply(get_weekday)

# %%
data['bathrooms'] = list(map(round, data['bathrooms']))

# %%
def season_sold(x):
    if x == 3 or x == 4 or x == 5:
        return 'Spring'
    elif x == 6 or x == 7 or x == 8:
        return 'Summer'
    elif x == 9 or x == 10 or x == 11:
        return 'Autumn'
    elif x == 12 or x == 1 or x== 2:
        return 'Winter'

# %%
data['season'] = data.month_sold.apply(season_sold)

# %%
def house_age(x):
    return int(2020 - int(x))

# %%
data['house_age'] = data.yr_built.apply(house_age)

# %%
data.zipcode
# Out:
# 0        98178
# 1        98125
# 2        98028
# 3        98136
# 4        98074
#          ...
# 21592    98103
# 21593    98146
# 21594    98144
# 21595    98027
# 21596    98144
# Name: zipcode, Length: 21597, dtype: int64

# %%
data.nunique()
# Out:
# id                21420
# date                372
# bedrooms             12
# bathrooms             9
# sqft_living        1034
# sqft_lot           9776
# floors                6
# waterfront            2
# view                  5
# condition             5
# grade                11
# sqft_above          942
# sqft_basement       306
# yr_built            116
# yr_renovated         70
# zipcode              70
# lat                5033
# long                751
# sqft_living15       777
# sqft_lot15         8682
# price              3622
# month_sold           12
# year_sold             2
# week_year_sold       53
# week_day              7
# season                4
# house_age           116
# dtype: int64

# %%
def get_center_facility(x):
    x = str(x)
    return x[1:3]

# %%
import h3

# %%
def hex_3_point(lat, long):
    return h3.geo_to_h3(lat=lat, lng = long, resolution=5)

# %%
data['hex_3'] = data.apply(lambda x: hex_3_point(x['lat'], x['long']), axis=1)

# %%
len(data['hex_3'].unique())
# Out:
# 26

# %%
len(data['lat'].unique())
# Out:
# 5033

# %%
data.groupby('hex_3').agg({'price':['min', 'mean','max']})
# Out:
#                   price
#                     min           mean      max
# hex_3
# 8528d087fffffff  210000  384448.611111   637000
# 8528d093fffffff  295000  295000.000000   295000
# 8528d097fffffff   80000  492765.583893  2280000
# 8528d09bfffffff  170000  290000.000000   415000
# 8528d407fffffff  380000  380000.000000   380000
# 8528d423fffffff  175000  376915.343750  1490000
# 8528d427fffffff  110000  444141.516129  1700000
# 8528d42bfffffff  230000  469492.295302  1950000
# 8528d42ffffffff  170000  540202.636792  2700000
# 8528d433fffffff  160000  414323.882353   667000
# 8528d437fffffff  105000  343539.965021  1180000
# 8528d46ffffffff  134000  186090.909091   375000
# 8528d477fffffff  525000  525000.000000   525000
# 8528d4affffffff  122000  301137.514851   858000
# 8528d543fffffff  130000  794607.221487  7700000
# 8528d547fffffff  125000  588625.464781  3800000
# 8528d54bfffffff   90000  594560.495475  1940000
# 8528d54ffffffff  130000  437711.406566  4500000
# 8528d553fffffff   78000  467897.451152  5300000
# 8528d557fffffff   90000  491088.223027  2230000
# 8528d55bfffffff  170000  708968.975227  3570000
# 8528d5c3fffffff   86500  284018.250000  1280000
# 8528d5c7fffffff  255000  442892.857143   575000
# 8528d5cbfffffff   85000  300955.893354  1230000
# 8528d5cffffffff  100000  450834.074786  2510000
# 8528d5dbfffffff  100000  273000.079800   900000

# %%
plt.figure(figsize = (12, 6))
sns.boxplot(x = 'hex_3', y = 'price',  data = data)
xt = plt.xticks(rotation=45)

# %%
sns.countplot(x='hex_3', data=data)
# Out:
# <AxesSubplot:xlabel='hex_3', ylabel='count'>

# %%
data['center_facility'] = data['zipcode'].apply(get_center_facility)

# %%
zip_codes_grouping = data.groupby('center_facility').agg({'price':['mean', 'min', 'max']})

# %%
data = data.drop(['date'], axis=1)

# %% [markdown]
# ### Checking for Multi-Collinearity

# %%
# data = data.drop(['id'], axis=1)
corr=data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col0,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow1_col1,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow2_col2,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow3_col3,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow4_col4,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow5_col5,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow6_col6,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow7_col7,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow8_col8,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow9_col9,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow10_col10,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow11_col11,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow12_col12,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow13_col13,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow14_col14,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow15_col15,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow16_col16,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow17_col17,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow18_col18,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow19_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow19_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow20_col20,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow21_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow21_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow22_col22,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow23_col23{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col1,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow4_col8,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow9_col18{
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col2,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow7_col23,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow9_col4{
#             background-color:  #f7b396;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col3,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow3_col6,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow10_col17,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow19_col14,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow21_col14{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col4,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow2_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow4_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow4_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow12_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow12_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow14_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow14_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow15_col8{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col5,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow22_col5{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col6,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow22_col0{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col7,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow12_col2,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow14_col16,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow19_col1,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow19_col7,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow21_col7{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col8,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow1_col0{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col9,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow2_col0,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow8_col4,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow16_col1{
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col10,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow4_col15,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow6_col20,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow10_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow11_col20,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow13_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow13_col20,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow13_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow15_col20,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow16_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow16_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow17_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow17_col20,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow17_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow18_col6,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow18_col20{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col11,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow1_col4,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow16_col15{
#             background-color:  #eed0c0;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col12,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow7_col2,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow16_col7,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow22_col10{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col13,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow5_col10,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow17_col7{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col14,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow4_col17,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow8_col5,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow10_col5,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow20_col3{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col15,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow1_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow1_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow2_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow3_col20,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow5_col6,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow5_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow5_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow8_col0,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow8_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow8_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow9_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow9_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow10_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow23_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow23_col21{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col16,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow4_col1,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow15_col9{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col17,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow5_col17,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow9_col10,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow12_col14{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col18,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow5_col4{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col20,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow10_col11,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow10_col20,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow15_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow18_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow18_col21{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow0_col21,#T_c5e9faa4_6b88_11eb_b8a1_a4b1c1f4aebarow3_col19,#T_c5e9faa4_6b88_11eb_b8a1_a4

# %% [markdown]
# It appears that sqft_living, grade, sqft_above are correlated to the price. Additinally, some other points that are highly correlated:
# - sqft_above & sqft_living
# - sqft_living & bathrooms
# - grade & sqft_living
# - grade & sqft_above
# - grade & sqft_living15
# - sqft_above & living16

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  datetime64[ns]
#  2   bedrooms       21597 non-null  int64
#  3   bathrooms      21597 non-null  float64
#  4   sqft_living    21597 non-null  int64
#  5   sqft_lot       21597 non-null  int64
#  6   floors         21597 non-null  float64
#  7   waterfront     21597 non-null  int64
#  8   view           21597 non-null  int64
#  9   condition      21597 non-null  int64
#  10  grade          21597 non-null  int64
#  11  sqft_above     21597 non-null  int64
#  12  sqft_basement  21597 non-null  int64
#  13  yr_built       21597 non-null  int64
#  14  yr_renovated   21597 non-null  int64
#  15  zipcode        21597 non-null  int64
#  16  lat            21597 non-null  float64
#  17  long           21597 non-null  float64
#  18  sqft_living15  21597 non-null  int64
#  19  sqft_lot15     21597 non-null  int64
#  20  price          21597 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(16)
# memory usage: 3.5 MB

# %%
def columns_vif(df, target, drop=[]):
    
    from statsmodels.stats.outliers_influence import variance_inflation_factor 
    
    temporary_vif_frame = df.drop(drop, axis=1)
    
    dropped_vif_frame = temporary_vif_frame.drop(target, axis=1)
    cols = dropped_vif_frame.columns
    temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_vif_frame)

    vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]

    for i in range(len(cols)):
        print(str(cols[i]) + "--------" + str(vif[i]))

    return temporary_vif_frame

# %%
temp_data = columns_vif(data, 'price', ['zipcode', 'lat', 'long', 'date', 'hex_3'])
# Out:
# C:\Users\jw156\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# id--------3.622792044555815
# bedrooms--------1.635708495640464
# bathrooms--------2.932495383462598
# sqft_living--------inf
# sqft_lot--------2.0950867442950307
# floors--------1.919193743954411
# waterfront--------1.2067702727289857
# view--------1.3921423399278055
# condition--------1.0598250262099376
# grade--------3.2303817283016487
# sqft_above--------inf
# sqft_basement--------inf
# yr_built--------146.8834787992033
# yr_renovated--------1.023851821424052
# sqft_living15--------2.8131534192577536
# sqft_lot15--------2.1450184824223064
# hex_3_ints--------1.0602796696175119

# %%
X_train, X_test, y_train, y_test = scale_function(temp_data, 'price')

# %%
regression_model(X_train, X_test, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-205-95e786707fc2> in <module>
# ----> 1 regression_model(X_train, X_test, y_train, y_test)
#
# <ipython-input-202-228e46f13032> in regression_model(scaled_x_train, scaled_x_test, y_train, y_test, model)
#      18     model = RandomForestRegressor(n_estimators=10)
#      19     model.fit(x_poly_train, y_train)
# ---> 20     predictions = model.predict(scaled_x_test)
#      21
#      22     #Computing errors
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     781         check_is_fitted(self)
#     782         # Check data
# --> 783         X = self._validate_X_predict(X)
#     784
#     785         # Assign chunk of trees to jobs
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _validate_X_predict(self, X)
#     419         check_is_fitted(self)
#     420
# --> 421         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     422
#     423     @property
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     394         n_features = X.shape[1]
#     395         if self.n_features_ != n_features:
# --> 396             raise ValueError("Number of features of the model must "
#     397                              "match the input. Model n_features is %s and "
#     398                              "input n_features is %s "
#
# ValueError: Number of features of the model must match the input. Model n_features is 171 and input n_features is 17

# %% [markdown]
# # Graphs

# %%
data.plot(x='long',y='lat',style='.',alpha=0.2,figsize=(12,12));
plt.title('Price Sale Locations');

# %%
data["hex_3"] = data["hex_3"].astype('object')

# %%
data.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# price                     int64
# hex_3                    object
# hex_3_ints                 int8
# dtype: object

# %%
data["hex_3_ints"] = data["hex_3"].cat.codes
data.head()
# Out:
#            id       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520 2014-10-13         3       1.00         1180      5650     1.0
# 1  6414100192 2014-12-09         3       2.25         2570      7242     2.0
# 2  5631500400 2015-02-25         2       1.00          770     10000     1.0
# 3  2487200875 2014-12-09         4       3.00         1960      5000     1.0
# 4  1954400510 2015-02-18         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  yr_built  yr_renovated  zipcode      lat  \
# 0           0     0          3  ...      1955             0    98178  47.5112
# 1           0     0          3  ...      1951          1991    98125  47.7210
# 2           0     0          3  ...      1933             0    98028  47.7379
# 3           0     0          5  ...      1965             0    98136  47.5208
# 4           0     0          3  ...      1987             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15   price            hex_3  hex_3_ints
# 0 -122.257           1340        5650  221900  8528d553fffffff          18
# 1 -122.319           1690        7639  538000  8528d54ffffffff          17
# 2 -122.233           2720        8062  180000  8528d54ffffffff          17
# 3 -122.393           1360        5000  604000  8528d557fffffff          19
# 4 -122.045           1800        7503  510000  8528d55bfffffff          20
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Scaler

# %%
def scale_function(df, target, scaler=StandardScaler(), random_seed = 100):
    y = df[target]
    X = df.drop([target], axis=1)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=random_seed)

    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)

    return X_train, X_test, y_train, y_test

# %%
temporary_df = columns_vif(data, 'price', drop=['sqft_living15', 'id'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-183-b9372e657777> in <module>
# ----> 1 temporary_df = columns_vif(data, 'price', drop=['sqft_living15', 'id'])
#
# <ipython-input-171-5fd22b3a490b> in columns_vif(df, target, drop)
#       9     temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_vif_frame)
#      10
# ---> 11     vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]
#      12
#      13     for i in range(len(cols)):
#
# <ipython-input-171-5fd22b3a490b> in <listcomp>(.0)
#       9     temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_vif_frame)
#      10
# ---> 11     vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]
#      12
#      13     for i in range(len(cols)):
#
# ~\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py in variance_inflation_factor(exog, exog_idx)
#     190     mask = np.arange(k_vars) != exog_idx
#     191     x_noti = exog[:, mask]
# --> 192     r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     193     vif = 1. / (1. - r_squared_i)
#     194     return vif
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     870     def __init__(self, endog, exog=None, missing='none', hasconst=None,
#     871                  **kwargs):
# --> 872         super(OLS, self).__init__(endog, exog, missing=missing,
#     873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     701         else:
#     702             weights = weights.squeeze()
# --> 703         super(WLS, self).__init__(endog, exog, missing=missing,
#     704                                   weights=weights, hasconst=hasconst, **kwargs)
#     705         nobs = self.exog.shape[0]
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     188     """
#     189     def __init__(self, endog, exog, **kwargs):
# --> 190         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     191         self._data_attr.extend(['pinv_wexog', 'weights'])
#     192
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     235
#     236     def __init__(self, endog, exog=None, **kwargs):
# --> 237         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     238         self.initialize()
#     239
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      75         missing = kwargs.pop('missing', 'none')
#      76         hasconst = kwargs.pop('hasconst', None)
# ---> 77         self.data = self._handle_data(endog, exog, missing, hasconst,
#      78                                       **kwargs)
#      79         self.k_constant = self.data.k_constant
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      99
#     100     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 101         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     102         # kwargs arrays could have changed, easier to just attach here
#     103         for key in kwargs:
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     670
#     671     klass = handle_data_class_factory(endog, exog)
# --> 672     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     673                  **kwargs)
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      85         self.const_idx = None
#      86         self.k_constant = 0
# ---> 87         self._handle_constant(hasconst)
#      88         self._check_integrity()
#      89         self._cache = {}
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     130             check_implicit = False
#     131             exog_max = np.max(self.exog, axis=0)
# --> 132             if not np.isfinite(exog_max).all():
#     133                 raise MissingDataError('exog contains inf or nans')
#     134             exog_min = np.min(self.exog, axis=0)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
scaled_x_train, scaled_x_test, y_train, y_test = scale_function(temporary_df, 'price', MinMaxScaler())

# %% [markdown]
# linear, polynomial, nearest  neighbour, random_forrest

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.ensemble import RandomForestRegressor

# %%
def regression_model(scaled_x_train, scaled_x_test, y_train, y_test, model=LinearRegression()):
    
    model= LinearRegression()
    Reg_model=model.fit(scaled_x_train, y_train)
    predictions = model.predict(scaled_x_test)

    model = PolynomialFeatures(2)
    x_poly_train = model.fit_transform(scaled_x_train)
    x_poly_test = model.fit_transform(scaled_x_test)
    model = LinearRegression()
    model.fit(x_poly_train, y_train)
    predictions = model.predict(x_poly_test)

    model = KNeighborsClassifier(n_neighbors=2, radius=0.4)
    reg_model = model.fit(scaled_x_train, y_train)
    predictions = model.predict(scaled_x_test)
    
    
    
    #Computing errors
    mse = mean_squared_error(y_test, predictions)
    rmse = math.sqrt(mse)
    mae = mean_absolute_error(y_test, predictions)
    r2 = r2_score(y_test, predictions)
    print('RMSE is -- ' + str(round(rmse,2)))
    print('MAE is -- ' + str(round(mae,2)))
    print('MSE is -- ' + str(round(mse,2)))
    print('R2 is -- ' + str(r2))

    plt.scatter(x=y_test, y= predictions, s=10)
    plt.show()

# %%
# model = RandomForestRegressor(n_estimators=10)
#     model.fit(x_poly_train, y_train)
#     predictions = model.predict(scaled_x_test)

# %%
regression_model(X_train, X_test, y_train, y_test, LinearRegression())
# Out:
# RMSE is -- 247194.15
# MAE is -- 132552.69
# MSE is -- 61104945478.65
# R2 is -- 0.5872669772876903

# %%
temporary_dropped_model = columns_vif(data, 'price', ['sqft_living15'])
# Out:
# C:\Users\jw156\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# id--------3.631154105275809
# bedrooms--------1.647480301544481
# bathrooms--------3.363161384313586
# sqft_living--------inf
# sqft_lot--------2.0946425018742536
# floors--------1.9115640128187872
# waterfront--------1.2030634214617124
# view--------1.3921976786982084
# condition--------1.2200994274885364
# grade--------3.1428294765561375
# sqft_above--------inf
# sqft_basement--------inf
# yr_built--------2.1281917344023054
# yr_renovated--------1.1428686283112226
# zipcode--------0.48229062232105535
# lat--------1.1775280620042805
# long--------1.7784375216220707
# sqft_lot15--------2.1337848842390548

# %%
scale_split_function(temporary_dropped_model, 'price')
# Out:
# (array([[ 1.38504104,  0.66985482,  1.13871678, ...,  0.48982312,
#           0.86389874, -0.17809727],
#         [ 0.17989123, -0.40062556, -0.47937847, ..., -0.21632151,
#           2.70965163, -0.05718199],
#         [-0.36829051, -1.47110595, -0.47937847, ..., -1.31001111,
#          -0.74758551, -0.32313678],
#         ...,
#         [-1.23507933, -0.40062556, -0.80299752, ..., -1.69175014,
#          -0.8043779 , -0.10653367],
#         [ 0.19706731, -0.40062556,  0.16785963, ..., -1.71642529,
#          -0.98895319,  0.08138516],
#         [-0.43391003,  1.7403352 ,  2.43319298, ..., -0.30123305,
#           0.07590424, -0.27165217]]),
#  array([[-0.91553093, -1.47110595, -1.45023562, ...,  0.61319886,
#          -0.72628836, -0.30842689],
#         [ 0.18011078, -0.40062556,  0.49147868, ..., -1.52337855,
#           1.5312094 , -0.31033917],
#         [-0.08492363, -1.47110595, -1.45023562, ...,  1.15387487,
#          -0.96055699, -0.20361893],
#         ...,
#         [ 1.1373777 , -0.40062556,  0.49147868, ..., -0.21922447,
#           2.56057159, -0.3063675 ],
#         [-0.08952235, -0.40062556,  0.16785963, ..., -0.62128422,
#          -0.86826935, -0.09737676],
#         [-0.97955952,  0.66985482, -0.47937847, ...,  1.29902279,
#           0.7432149 , -0.04364889]]),
#  17798    592500
#  1989     299000
#  3996     210000
#  12688    425000
#  14576    657000
#            ...
#  16304    274950
#  79       720000
#  12119    219950
#  14147    212000
#  5640     980000
#  Name: price, Length: 14469, dtype: int64,
#  7189     900000
#  2751     346950
#  17077    305000
#  15151    507000
#  985      283000
#            ...
#  21084    712198
#  12121    650000
#  2753     410000
#  304      315000
#  11958    484000
#  Name: price, Length: 7128, dtype: int64)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 

dropped_data = data.drop(['price', 'date'], axis=1)
cols = dropped_data.columns
temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_data)

vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]

for i in range(len(cols)):
    print(str(cols[i]) + "--------" + str(vif[i]))
# Out:
# id--------3.631154334388575
# bedrooms--------1.6474823444122422
# bathrooms--------3.3664940208446854
# sqft_living--------inf
# sqft_lot--------2.101815044520409
# floors--------1.9538473541349937
# waterfront--------1.2039809847997307
# view--------1.4206464395388392
# condition--------1.2202464183262423
# grade--------3.4048549421594334
# sqft_above--------inf
# sqft_basement--------inf
# yr_built--------2.1311213972387524
# yr_renovated--------1.1448119229263023
# zipcode--------0.48799172188677403
# lat--------1.1801452292778827
# long--------1.812130624022116
# sqft_living15--------2.8849730272651852
# sqft_lot15--------2.140664402064274

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 

dropped_data = data.drop(['price', 'sqft_basement', 'yr_built'], axis=1)
cols = dropped_data.columns
temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_data)

vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]

for i in range(len(cols)):
    print(str(cols[i]) + "--------" + str(vif[i]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-ff28026ec632> in <module>
#       5 temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_data)
#       6
# ----> 7 vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]
#       8
#       9 for i in range(len(cols)):
#
# <ipython-input-58-ff28026ec632> in <listcomp>(.0)
#       5 temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_data)
#       6
# ----> 7 vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]
#       8
#       9 for i in range(len(cols)):
#
# ~\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py in variance_inflation_factor(exog, exog_idx)
#     190     mask = np.arange(k_vars) != exog_idx
#     191     x_noti = exog[:, mask]
# --> 192     r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     193     vif = 1. / (1. - r_squared_i)
#     194     return vif
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     870     def __init__(self, endog, exog=None, missing='none', hasconst=None,
#     871                  **kwargs):
# --> 872         super(OLS, self).__init__(endog, exog, missing=missing,
#     873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     701         else:
#     702             weights = weights.squeeze()
# --> 703         super(WLS, self).__init__(endog, exog, missing=missing,
#     704                                   weights=weights, hasconst=hasconst, **kwargs)
#     705         nobs = self.exog.shape[0]
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     188     """
#     189     def __init__(self, endog, exog, **kwargs):
# --> 190         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     191         self._data_attr.extend(['pinv_wexog', 'weights'])
#     192
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     235
#     236     def __init__(self, endog, exog=None, **kwargs):
# --> 237         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     238         self.initialize()
#     239
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      75         missing = kwargs.pop('missing', 'none')
#      76         hasconst = kwargs.pop('hasconst', None)
# ---> 77         self.data = self._handle_data(endog, exog, missing, hasconst,
#      78                                       **kwargs)
#      79         self.k_constant = self.data.k_constant
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      99
#     100     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 101         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     102         # kwargs arrays could have changed, easier to just attach here
#     103         for key in kwargs:
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     670
#     671     klass = handle_data_class_factory(endog, exog)
# --> 672     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     673                  **kwargs)
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      85         self.const_idx = None
#      86         self.k_constant = 0
# ---> 87         self._handle_constant(hasconst)
#      88         self._check_integrity()
#      89         self._cache = {}
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     130             check_implicit = False
#     131             exog_max = np.max(self.exog, axis=0)
# --> 132             if not np.isfinite(exog_max).all():
#     133                 raise MissingDataError('exog contains inf or nans')
#     134             exog_min = np.min(self.exog, axis=0)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 

dropped_data = data.drop(['price', 'sqft_basement', 'lat', 'long'], axis=1)
cols = dropped_data.columns
temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_data)

vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]

for i in range(len(cols)):
    print(str(cols[i]) + "--------" + str(vif[i]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-aa1fc47e96be> in <module>
#       5 temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_data)
#       6
# ----> 7 vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]
#       8
#       9 for i in range(len(cols)):
#
# <ipython-input-59-aa1fc47e96be> in <listcomp>(.0)
#       5 temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_data)
#       6
# ----> 7 vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]
#       8
#       9 for i in range(len(cols)):
#
# ~\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py in variance_inflation_factor(exog, exog_idx)
#     190     mask = np.arange(k_vars) != exog_idx
#     191     x_noti = exog[:, mask]
# --> 192     r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     193     vif = 1. / (1. - r_squared_i)
#     194     return vif
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     870     def __init__(self, endog, exog=None, missing='none', hasconst=None,
#     871                  **kwargs):
# --> 872         super(OLS, self).__init__(endog, exog, missing=missing,
#     873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     701         else:
#     702             weights = weights.squeeze()
# --> 703         super(WLS, self).__init__(endog, exog, missing=missing,
#     704                                   weights=weights, hasconst=hasconst, **kwargs)
#     705         nobs = self.exog.shape[0]
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     188     """
#     189     def __init__(self, endog, exog, **kwargs):
# --> 190         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     191         self._data_attr.extend(['pinv_wexog', 'weights'])
#     192
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     235
#     236     def __init__(self, endog, exog=None, **kwargs):
# --> 237         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     238         self.initialize()
#     239
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      75         missing = kwargs.pop('missing', 'none')
#      76         hasconst = kwargs.pop('hasconst', None)
# ---> 77         self.data = self._handle_data(endog, exog, missing, hasconst,
#      78                                       **kwargs)
#      79         self.k_constant = self.data.k_constant
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      99
#     100     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 101         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     102         # kwargs arrays could have changed, easier to just attach here
#     103         for key in kwargs:
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     670
#     671     klass = handle_data_class_factory(endog, exog)
# --> 672     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     673                  **kwargs)
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      85         self.const_idx = None
#      86         self.k_constant = 0
# ---> 87         self._handle_constant(hasconst)
#      88         self._check_integrity()
#      89         self._cache = {}
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     130             check_implicit = False
#     131             exog_max = np.max(self.exog, axis=0)
# --> 132             if not np.isfinite(exog_max).all():
#     133                 raise MissingDataError('exog contains inf or nans')
#     134             exog_min = np.min(self.exog, axis=0)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
scale_split_function(temporary_cleaned_data, 'price')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-1bed32f90c10> in <module>
# ----> 1 scale_split_function(temporary_cleaned_data, 'price')
#
# <ipython-input-32-bb077bbe937c> in scale_split_function(df, target, scaler)
#       1 def scale_split_function(df, target, scaler='StandardScaler'):
# ----> 2     X = df.drop([target], axis=1)
#       3     y = df.target
#       4
#       5     from sklearn.model_selection import train_test_split
#
# AttributeError: 'numpy.ndarray' object has no attribute 'drop'

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 

dropped_data = data.drop(['price', 'sqft_basement', 'lat', 'long', 'sqft_living', 'sqft_lot' , 'yr_built'], axis=1)
cols = dropped_data.columns
temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_data)

vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]

for i in range(len(cols)):
    print(str(cols[i]) + "--------" + str(vif[i]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-7635ae32782f> in <module>
#       5 temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_data)
#       6
# ----> 7 vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]
#       8
#       9 for i in range(len(cols)):
#
# <ipython-input-60-7635ae32782f> in <listcomp>(.0)
#       5 temporary_cleaned_data = pd.DataFrame.to_numpy(dropped_data)
#       6
# ----> 7 vif = [variance_inflation_factor(temporary_cleaned_data, i) for i in range(temporary_cleaned_data.shape[1])]
#       8
#       9 for i in range(len(cols)):
#
# ~\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py in variance_inflation_factor(exog, exog_idx)
#     190     mask = np.arange(k_vars) != exog_idx
#     191     x_noti = exog[:, mask]
# --> 192     r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     193     vif = 1. / (1. - r_squared_i)
#     194     return vif
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     870     def __init__(self, endog, exog=None, missing='none', hasconst=None,
#     871                  **kwargs):
# --> 872         super(OLS, self).__init__(endog, exog, missing=missing,
#     873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     701         else:
#     702             weights = weights.squeeze()
# --> 703         super(WLS, self).__init__(endog, exog, missing=missing,
#     704                                   weights=weights, hasconst=hasconst, **kwargs)
#     705         nobs = self.exog.shape[0]
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     188     """
#     189     def __init__(self, endog, exog, **kwargs):
# --> 190         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     191         self._data_attr.extend(['pinv_wexog', 'weights'])
#     192
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     235
#     236     def __init__(self, endog, exog=None, **kwargs):
# --> 237         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     238         self.initialize()
#     239
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      75         missing = kwargs.pop('missing', 'none')
#      76         hasconst = kwargs.pop('hasconst', None)
# ---> 77         self.data = self._handle_data(endog, exog, missing, hasconst,
#      78                                       **kwargs)
#      79         self.k_constant = self.data.k_constant
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      99
#     100     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 101         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     102         # kwargs arrays could have changed, easier to just attach here
#     103         for key in kwargs:
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     670
#     671     klass = handle_data_class_factory(endog, exog)
# --> 672     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     673                  **kwargs)
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      85         self.const_idx = None
#      86         self.k_constant = 0
# ---> 87         self._handle_constant(hasconst)
#      88         self._check_integrity()
#      89         self._cache = {}
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     130             check_implicit = False
#     131             exog_max = np.max(self.exog, axis=0)
# --> 132             if not np.isfinite(exog_max).all():
#     133                 raise MissingDataError('exog contains inf or nans')
#     134             exog_min = np.min(self.exog, axis=0)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# **Correlation is highly correlated & needs to be transformed**

# %% [markdown]
# **Step_1**: drop 1 highly correlated feature highly correlated:
#  - drop zipcode
#  - year_sold

# %%
X = data.drop(['zipcode', 'year_sold'], axis=1)
  
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 
  
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) 
                          for i in range(len(X.columns))] 
  
print(vif_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-935a999bf950> in <module>
# ----> 1 X = data.drop(['zipcode', 'year_sold'], axis=1)
#       2
#       3 # VIF dataframe
#       4 vif_data = pd.DataFrame()
#       5 vif_data["feature"] = X.columns
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['year_sold'] not found in axis"

# %% [markdown]
# **Step_2**: transform highly correlated feature:
#  - month_sold to season_sold
#  - yr_built to house_age

# %%
data['house_age'].unique
# Out:
# <bound method Series.unique of 0        65
# 1        69
# 2        87
# 3        55
# 4        33
#          ..
# 21592    11
# 21593     6
# 21594    11
# 21595    16
# 21596    12
# Name: house_age, Length: 21597, dtype: int64>

# %%
trans_data = pd.get_dummies(data,columns=["season"],drop_first=True)

# %%
corr=trans_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col0,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow1_col1,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow2_col2,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow3_col3,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow4_col4,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow5_col5,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow6_col6,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow7_col7,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow8_col8,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow9_col9,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow10_col10,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow11_col11,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow12_col12,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow13_col13,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow14_col14,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow15_col15,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow16_col16,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow17_col17,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow18_col18,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow19_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow20_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow21_col21,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow22_col22,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow23_col23,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow24_col24{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col1,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow4_col8,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow9_col18{
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col2,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow7_col21,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow9_col4{
#             background-color:  #f7b396;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col3,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow3_col6,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow10_col17,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow19_col14,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow22_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow23_col14{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col4,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow2_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow4_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow12_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow14_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow15_col8{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col5{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col6,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow23_col0{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col7,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow12_col2,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow14_col16,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow19_col1,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow19_col7{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col8,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow1_col0{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col9,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow2_col0,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow8_col4,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow16_col1{
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col10,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow4_col15,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow6_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow11_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow13_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow13_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow15_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow16_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow17_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow17_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow18_col6,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow18_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow20_col24{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col11,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow1_col4,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow16_col15{
#             background-color:  #eed0c0;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col12,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow7_col2,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow16_col7,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow22_col10{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col13,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow5_col10,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow17_col7{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col14,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow4_col17,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow8_col5,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow10_col5,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow20_col3,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow22_col3,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow24_col3{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col15,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow1_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow3_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow5_col6,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow5_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow8_col0,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow8_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow9_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow10_col19,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow21_col19{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col16,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow4_col1,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow15_col9{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col17,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow5_col17,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow9_col10,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow12_col14{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col18,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow5_col4,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow6_col22,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow10_col22,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow12_col22,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow14_col22,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow15_col22,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow21_col22{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow10_col11,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow10_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow18_col19{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow0_col21,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow1_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow2_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow6_col1,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow9_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow10_col8,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow12_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow14_col20,#T_88fb2570_6ac9_11eb_a3b8_a4b1c1f4aebarow15_col2{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T

# %%
trans_data = trans_data.drop(['yr_built'], axis=1)
ck = pd.DataFrame.to_numpy(trans_data)

vif = [variance_inflation_factor(ck, i) for i in range(ck.shape[1])]
colums = trans_data.columns
for i in range(len(colums)):
    print(str(colums[i]) + "--------" + str(vif[i]))
# Out:
# bedrooms--------23.720712496911922
# bathrooms--------19.630048015356525
# sqft_living--------inf
# sqft_lot--------2.3810815753609167
# floors--------16.449364650794916
# waterfront--------1.2780068814857586
# view--------1.6147288752162656
# condition--------35.76081629660667
# grade--------163.49572106163478
# sqft_above--------inf
# sqft_basement--------inf
# yr_renovated--------1.1957714947362241
# zipcode--------5463928.118196141
# lat--------159618.5217561194
# long--------1397244.0589639028
# sqft_living15--------28.183090262382557
# sqft_lot15--------2.6045279047578087
# price--------10.639015501086533
# month_sold--------11.088555675380364
# year_sold--------4196002.7521931445
# house_age--------9.124789947685056
# season_Spring--------4.3558497744783695
# season_Summer--------2.7982878113719174
# season_Winter--------2.344198975920313
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-89-d0f8a3965fe7> in <module>
#       5 colums = trans_data.columns
#       6 for i in range(25):
# ----> 7     print(str(colums[i]) + "--------" + str(vif[i]))
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4099         if is_scalar(key):
#    4100             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4101             return getitem(key)
#    4102
#    4103         if isinstance(key, slice):
#
# IndexError: index 24 is out of bounds for axis 0 with size 24

# %%
trans_data = trans_data.drop(['lat', 'long'], axis=1)
ck = pd.DataFrame.to_numpy(trans_data)

vif = [variance_inflation_factor(ck, i) for i in range(ck.shape[1])]
colums = trans_data.columns
for i in range(len(colums)):
    print(str(colums[i]) + "--------" + str(vif[i]))
# Out:
# C:\Users\jw156\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# bedrooms--------1.662592668580318
# bathrooms--------2.319550801401652
# sqft_living--------inf
# sqft_lot--------2.0901705649512134
# floors--------1.8792621241994552
# waterfront--------1.2586946055829418
# view--------1.4446804438414147
# condition--------1.253677300990059
# grade--------3.6966241644513804
# sqft_above--------inf
# sqft_basement--------inf
# yr_built--------81688248.37870273
# yr_renovated--------1.14253007421491
# zipcode--------1.3076644031687057
# sqft_living15--------2.923999998582993
# sqft_lot15--------2.1238757506404244
# price--------2.9239633266630705
# month_sold--------3.870484942784122
# year_sold--------4.368109603137341
# house_age--------68717.4690222289
# season_Spring--------3.122572609856965
# season_Summer--------2.3218877844648222
# season_Winter--------2.029151862952084

# %%
trans_data = trans_data.drop(['yr_built'], axis=1)
ck = pd.DataFrame.to_numpy(trans_data)

vif = [variance_inflation_factor(ck, i) for i in range(ck.shape[1])]
colums = trans_data.columns
for i in range(len(colums)):
    print(str(colums[i]) + "--------" + str(vif[i]))
# Out:
# bedrooms--------23.70919455638547
# bathrooms--------19.610584369283647
# sqft_living--------inf
# sqft_lot--------2.3673514644170663
# floors--------16.266955175987125
# waterfront--------1.2682495649036614
# view--------1.5790028226553545
# condition--------35.54313916556934
# grade--------161.15436570031108
# sqft_above--------inf
# sqft_basement--------inf
# yr_renovated--------1.190899740101807
# zipcode--------4153953.766210816
# sqft_living15--------27.457613430035536
# sqft_lot15--------2.5885691346543935
# price--------9.23303487191025
# month_sold--------11.074748770696106
# year_sold--------4149950.83900202
# house_age--------8.670153990767549
# season_Spring--------4.355849216842694
# season_Summer--------2.797969484002621
# season_Winter--------2.343882526248106

# %%
trans_data.year_sold.unique()
# Out:
# array([2014, 2015], dtype=int64)

# %% [markdown]
# # Graphs

# %%
graph_data = data.drop(['id'], axis=1)

# %%
for col in graph_data.columns:
    sns.distplot(graph_data[col], kde=False);
    plt.show()
# Out:
# C:\Users\jw156\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
intz = data.select_dtypes(include=np.int64)
intz = intz.drop(['id'], axis=1)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from shapely.geometry import Point
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-728d012ab5d9> in <module>
# ----> 1 import geopandas as gpd
#       2 import matplotlib.pyplot as plt
#       3 import contextily as ctx
#       4 from shapely.geometry import Point
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
for col in intz.columns:
    sns.countplot(x=col, data=intz)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-2628e4627050> in <module>
#       1 for col in intz.columns:
#       2     sns.countplot(x=col, data=intz)
# ----> 3     plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         FigureCanvasAgg.draw(self)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1163
#    1164         ticks_to_draw = self._update_ticks()
# -> 1165         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1166                                                                 renderer)
#    1167
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     898
#     899         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 900             bbox, info, descent = self._get_layout(self._renderer)
#     901             x, y = self.get_unitless_position()
#     902             x, y = self.get_transform().transform((x, y))
#
# ~\Anaconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     291             clean_line, ismath = self._preprocess_math(line)
#     292             if clean_line:
# --> 293                 w, h, d = renderer.get_text_width_height_descent(
#     294                     clean_line, self._fontproperties, ismath=ismath)
#     295             else:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     235
#     236         flags = get_hinting_flag()
# --> 237         font = self._get_agg_font(prop)
#     238         font.set_text(s, 0.0, flags=flags)
#     239         w, h = font.get_width_height()  # width and height of unrotated string
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in _get_agg_font(self, prop)
#     270         Get the font for text instance t, caching for efficiency
#     271         """
# --> 272         fname = findfont(prop)
#     273         font = get_font(fname)
#     274
#
# ~\Anaconda3\lib\site-packages\matplotlib\font_manager.py in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1312             prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1313             rc_params)
# -> 1314         return os.path.realpath(filename)
#    1315
#    1316     @lru_cache()
#
# ~\Anaconda3\lib\ntpath.py in realpath(path)
#     662             # Ensure that the non-prefixed path resolves to the same path
#     663             try:
# --> 664                 if _getfinalpathname(spath) == path:
#     665                     path = spath
#     666             except OSError as ex:
#
# KeyboardInterrupt:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  datetime64[ns]
#  2   bedrooms       21597 non-null  int64
#  3   bathrooms      21597 non-null  float64
#  4   sqft_living    21597 non-null  int64
#  5   sqft_lot       21597 non-null  int64
#  6   floors         21597 non-null  float64
#  7   waterfront     21597 non-null  int64
#  8   view           21597 non-null  int64
#  9   condition      21597 non-null  int64
#  10  grade          21597 non-null  int64
#  11  sqft_above     21597 non-null  int64
#  12  sqft_basement  21597 non-null  int64
#  13  yr_built       21597 non-null  int64
#  14  yr_renovated   21597 non-null  int64
#  15  zipcode        21597 non-null  int64
#  16  lat            21597 non-null  float64
#  17  long           21597 non-null  float64
#  18  sqft_living15  21597 non-null  int64
#  19  sqft_lot15     21597 non-null  int64
#  20  price          21597 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(16)
# memory usage: 3.5 MB

# %%
data.describe()
# Out:
#                  id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  2.159700e+04
# mean   4.580474e+09      3.373200      2.115826   2080.321850  1.509941e+04
# std    2.876736e+09      0.926299      0.768984    918.106125  4.141264e+04
# min    1.000102e+06      1.000000      0.500000    370.000000  5.200000e+02
# 25%    2.123049e+09      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    3.904930e+09      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    7.308900e+09      4.000000      2.500000   2550.000000  1.068500e+04
# max    9.900000e+09     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21597.000000  21597.000000  21597.000000  21597.000000  21597.000000
# mean       1.494096      0.007547      0.234292      3.409825      7.657915
# std        0.539683      0.086549      0.766390      0.650546      1.173200
# min        1.000000      0.000000      0.000000      1.000000      3.000000
# 25%        1.000000      0.000000      0.000000      3.000000      7.000000
# 50%        1.500000      0.000000      0.000000      3.000000      7.000000
# 75%        2.000000      0.000000      0.000000      4.000000      8.000000
# max        3.500000      1.000000      4.000000      5.000000     13.000000
#
#          sqft_above  sqft_basement      yr_built  yr_renovated       zipcode  \
# count  21597.000000   21597.000000  21597.000000  21597.000000  21597.000000
# mean    1788.596842     291.725008   1970.999676     84.464787  98077.951845
# std      827.759761     442.667800     29.375234    401.821438     53.513072
# min      370.000000       0.000000   1900.000000      0.000000  98001.000000
# 25%     1190.000000       0.000000   1951.000000      0.000000  98033.000000
# 50%     1560.000000       0.000000   1975.000000      0.000000  98065.000000
# 75%     2210.000000     560.000000   1997.000000      0.000000  98118.000000
# max     9410.000000    4820.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15         price
# count  21597.000000  21597.000000   21597.000000   21597.000000  2.159700e+04
# mean      47.560093   -122.213982    1986.620318   12758.283512  5.402966e+05
# std        0.138552      0.140724     685.230472   27274.441950  3.673681e+05
# min       47.155900   -122.519000     399.000000     651.000000  7.800000e+04
# 25%       47.471100   -122.328000    1490.000000    5100.000000  3.220000e+05
# 50%       47.571800   -122.231000    1840.000000    7620.000000  4.500000e+05
# 75%       47.678000   -122.125000    2360.000000   10083.000000  6.450000e+05
# max       47.777600   -121.315000    6210.000000  871200.000000  7.700000e+06

# %%
BBox = ((data.long.min(),   data.long.max(),      
         data.lat.min(), data.lat.max()))

# %%
BBox
# Out:
# (-122.519, -121.315, 47.1559, 47.7776)

# %%
data.nunique()
# Out:
# id               21420
# date               372
# bedrooms            12
# bathrooms           29
# sqft_living       1034
# sqft_lot          9776
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               11
# sqft_above         942
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5033
# long               751
# sqft_living15      777
# sqft_lot15        8682
# price             3622
# dtype: int64

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cbook import dedent
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-31b4185f77bc> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from matplotlib.cbook import dedent
#
# ImportError: cannot import name 'dedent' from 'matplotlib.cbook' (C:\Users\jw156\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py)
